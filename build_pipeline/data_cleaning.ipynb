# %%
import requests
import IPython

# %%
response = requests.get(r"https://www.udacity.com/courses/all")
print(response.text)
# Out:
# <!DOCTYPE html><html lang="en-US"><head><meta charSet="UTF-8"/><script type="text/javascript">window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").g ...
#         window.addEventListener('load', function() {analytics.page("Catalog", "Catalog - all", {site_identifier: "Next.Sites", ordered_results: "nd027,nd1309,nd002,nd104,nd025,nd018,nd256,nd036,nd213,nd0044,nd880,nd072,nd009t,nd098,nd0011,nd101,nd019,nd000,nd089,nd035,nd578,nd013,nd030,nd545,nd029,nd9991,nd9990,nd891,nd209,nd892,nd893,nd032,nd088,nd028,nd003,nd229,nd144,nd063,nd037-2,nd313,nd113,nd803,nd320,nd008t,nd197,nd230,nd787,nd131,nd037-3,nd082,nd898,nd118,nd054,nd045,nd037,nd00333,nd064,nd046,nd321,nd081,nd350,nd698,nd324,nd331,nd038,nd0067,nd079,nd303,nd940,nd340,ud723,ud509,ud518,ud979,ud034,ud099,ud953,ud741,ud758,ud827,ud132,ud954,ud185,ud919,ud507,ud501,ud262,ud617,ud381,ud257,ud651,ud409,ud190,ud810,ud187,ud104,cs271,cs373,ud188,ud014,ud600,ud120,ud9876,cs222,ud0419,ud0321,ud080,ud459,ud279,ud199,ud977,ud976,ud978,ud981,ud980,ud719,ep245,ud806,ud942,ud359,ud170,ud198,ud150,ud201,ud2002,ud404,ud091,ud892,ud894,ud893,ud595,ud808,ud839,ud884,ud421,ud989,ud836,ud825,ud882,ud774,ud867,ud905,ud898,ud788,ud834,ud897,ud994,ud890,ud855,ud821,ud330,ud585,ud923,ud843,ud891,ud845,ud615,ud9012,ud860,ud902,ud899,ud888,ud849,ud805,ud1006,ud811,ud777,ud333,ud325,ud436,ud353,ud400,ud405,ud245,ud401,ud268,ud406,ud549,ud711,ud610,ud168,ud292,ud283,ud388,ud098,ud803,ud576,ud1022,st101,ud001,ud851,ud1110,ud1012,ud1009,cs258,cs291,ud088,ud007,ud1026,ud9011,ud206,ud1038,st095,cs313,cs212,ud032,ud1025,ud0352,cs259,ud1000,ud1031,cs262,ud256,ph100,ud197,ud356,ud1034,ud110,cs215,ud270,ud667,ud109,ud169,ud281,ud303,ud940,ud061,ud189,ud1028,ud123,ud0351,ud162,ud272,cs387,ud282,ud210,ud171,ud117,ud354,ud299,ud607,ud611,ud864,ud357,ud358,ps001,ud407,ud862,ud244,ud243,ud242,ud944,ud241,ud1001,ud250,ud252,ud1011,ud240,ud251", results_count: "259", category_key: "all"});})</script><meta name="next-head-count" content="28"/><link rel="preload" href="/_next/static/css/3dc290b4eb4d84ee696c.css" as="style"/><link rel="stylesheet" href="/_next/static/css/3dc290b4eb4d84ee696c.css" data-n-g=""/><link rel="preload" href="/_next/static/css/689fc26086264deca3ab.css" as="style"/><link rel="stylesheet" href="/_next/static/css/689fc26086264deca3ab.css" data-n-g=""/><link rel="preload" href="/_next/static/css/dd2f137ef4e2c3a661da.css" as="style"/><link rel="stylesheet" href="/_next/static/css/dd2f137ef4e2c3a661da.css" data-n-p=""/><noscript data-n-css=""></noscript><link rel="preload" href="/_next/static/chunks/main-fddb6b72a850e25e079e.js" as="script"/><link rel="preload" href="/_next/static/chunks/webpack-67ca53b4aa97a3a242fc.js" as="script"/><link rel="preload" href="/_next/static/chunks/framework.0ba53a8de0b1a5f4cfd1.js" as="script"/><link rel="preload" href="/_next/static/chunks/commons.7bc859ec0334901ff59a.js" as="script"/><link rel="preload" href="/_next/static/chunks/pages/_app-c0a770661892a6f2ce76.js" as="script"/><link rel="preload" href="/_next/static/chunks/a4d6f50b0b6060e14d3255d4f06c75407729fe66.2a372f5bbfbd08fe3570.js" as="script"/><link rel="preload" href="/_next/static/chunks/8fdfd27ff7738eb10249d62acc49e93b3974be09.8a9f31843c56e56c7873.js" as="script"/><link rel="preload" href="/_next/static/chunks/pages/courses/%5Bslug%5D-6d69a98a9c20fca790c8.js" as="script"/></head><body><div id="__next"><div class="page-us"><div class=""><div class="us_mobileMenuWrap__3PkUm"><div><a class="catalog-nav-mobile_logoLink__363Sr" title="Udacity" href="/"><svg height="30" viewBox="0 0 180 30" width="180"><g fill="none" fill-rule="evenodd"><path d="M57.6 17.239187c0 2.546698-2.085517 4.407747-4.965517 4.407747-2.88 0-4.965517-1.86105-4.965517-4.407747V7.835994H45.68276v9.501143c0 3.330298 2.88 6.170846 6.951723 6.170846 4.071724 0 6.951724-2.938498 6.951724-6.170846V7.835994H57.6v9.403193zm16.286897-9.403193h-5.36276v15.67199h5.36276c4.468965 0 7.547586-3.03645 7.547586-7.835996 0-4.701596-3.07862-7.835994-7.547586-7.835994zm-.19862 13.71299h-3.177932V9.794994h3.17793c3.376553 0 5.76 2.252847 5.76 5.876994 0 3.917998-2.482757 5.779046-5.76 5.876996zm43.49793.2938 ...
# </p></div><ul class="_catalog-card-lemur_stats__S_MFm"><li data-level="beginner">beginner</li><li data-duration="">3 Months</li><li><div data-mobileonly="false" class="_catalog-card-lemur_reviews__m5pih"><div class="rating-stars_container__3no4V rating-stars_medium__26tP5"><div class="rating-stars_active__1v1eF" style="width:91.80327868852459%"></div><span class="rating-stars_visuallyHidden__3U2dC">91.80327868852459<!-- -->%</span></div><small>61<!-- --> reviews</small></div></li></ul><div class="_catalog-card-lemur_overview__1apEI"><section><h4>Skills Covered</h4><p>Agile, Scrum, Kanban, XP, Minimum Viable Product</p></section><section><h4>Prerequisites</h4><p>No Experience Required</p></section></div></div><div class="_catalog-card-lemur_actionButtonsContainer__3wxO4"><div><button class="btn button--primary">Program Details</button><button class="btn button--white-outlined">Download Syllabus</button></div><div><h4>In Collaboration With</h4><p>ThoughtWorks</p></div></div></article></a></li><li class="catalog-card-list_catalogCardListItem__AZBy6"><a href="/course/aws-cloud-architect-nanodegree--nd063" aria-label="AWS Cloud Architect" data-testid="catalog-card-lemur"><article class="_catalog-card-lemur_container__2u2VK"><div class="_catalog-card-lemur_imageContainer__3RKr4"><ul data-mobileonly="true" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><div class="_catalog-card-lemur_programImage__3wQ69" style="background-image:url(...)"></div></div><div class="_catalog-card-lemur_body__2kxzp"><div><ul data-mobileonly="false" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><h2>AWS Cloud Architect</h2><h3>School of Cloud Computing</h3><div data-mobileonly="true" class="_catalog-card-lemur_reviews__m5pih"><div class="rating-stars_container__3no4V rating-stars_medium__26tP5"><div class="rating-stars_active__1v1eF" style="width:92.20930232558139%"></div><span class="rating-stars_visuallyHidden__3U2dC">92.20930232558139<!-- -->%</span></div><small>172<!-- --> reviews</small></div><p>Lead your organization&#x27;s cloud computing strategy as an AWS Cloud Architect. Plan, design, and build secure, high availability cloud infrastructure.</p></div><ul class="_catalog-card-lemur_stats__S_MFm"><li data-level="advanced">advanced</li><li data-duration="">3 Months</li><li><div data-mobileonly="false" class="_catalog-card-lemur_reviews__m5pih"><div class="rating-stars_container__3no4V rating-stars_medium__26tP5"><div class="rating-stars_active__1v1eF" style="width:92.20930232558139%"></div><span class="rating-stars_visuallyHidden__3U2dC">92.20930232558139<!-- -->%</span></div><small>172<!-- --> reviews</small></div></li></ul><div class="_catalog-card-lemur_overview__1apEI"><section><h4>Skills Covered</h4><p>Cloud Infrastructure, Cloud Security, AWS, CloudFormation, High Availability Infrastructure, Serverless Computing</p></section><section><h4>Prerequisites</h4><p>Experience with Cloud Computing, Programming, and AWS</p></section></div></div><div class="_catalog-card-lemur_actionButtonsContainer__3wxO4"><div><button class="btn button--primary">Program Details</button><button class="btn button--white-outlined">Download Syllabus</button></div></div></article></a></li><li class="catalog-card-list_catalogCardListItem__AZBy6"><a href="/course/activation-and-retention-strategy--nd037-2" aria-label="Activation and Retention Strategy" data-testid="catalog-card-lemur"><article class="_catalog-card-lemur_container__2u2VK"><div class="_catalog-card-lemur_imageContainer__3RKr4"><ul data-mobileonly="true" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><div class="_catalog-card-lemur_programImage__3wQ69" style="background-image:url(...)"></div></div><div class="_catalog-card-lemur_body__2kxzp"><div><ul data-mobileonly="false" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type= ...
# </p></section><section><h4>Prerequisites</h4><p>Prior experience with Python, Machine Learning, and Statistics</p></section></div></div><div class="_catalog-card-lemur_actionButtonsContainer__3wxO4"><div><button class="btn button--primary">Program Details</button><button class="btn button--white-outlined">Download Syllabus</button></div><div><h4>In Collaboration With</h4><p>Microsoft</p></div></div></article></a></li><li class="catalog-card-list_catalogCardListItem__AZBy6"><a href="/course/cloud-native-application-architecture-nanodegree--nd064" aria-label="Cloud Native Application Architecture" data-testid="catalog-card-lemur"><article class="_catalog-card-lemur_container__2u2VK"><div class="_catalog-card-lemur_imageContainer__3RKr4"><ul data-mobileonly="true" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><div class="_catalog-card-lemur_programImage__3wQ69" style="background-image:url(...)"></div></div><div class="_catalog-card-lemur_body__2kxzp"><div><ul data-mobileonly="false" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><h2>Cloud Native Application Architecture</h2><h3>School of Cloud Computing</h3><p>Youâll master the skills necessary to become a successful cloud native architect. Learn to run and manage scalable applications in a cloud native environment, using open source tools and projects like ArgoCD, gRPC, and Grafana.</p></div><ul class="_catalog-card-lemur_stats__S_MFm"><li data-level="intermediate">intermediate</li><li data-duration="">4 Months</li><li></li></ul><div class="_catalog-card-lemur_overview__1apEI"><section><h4>Skills Covered</h4><p>Microservice architecture,  Kubernetes,  Continuous Integration,  Continuous Delivery,  Message Passing,  Observability,  Microservices security</p></section><section><h4>Prerequisites</h4><p>HTTP, Python, Git, Linux, Docker</p></section></div></div><div class="_catalog-card-lemur_actionButtonsContainer__3wxO4"><div><button class="btn button--primary">Program Details</button><button class="btn button--white-outlined">Download Syllabus</button></div><div><h4>In Collaboration With</h4><p>SUSE</p></div></div></article></a></li><li class="catalog-card-list_catalogCardListItem__AZBy6"><a href="/course/cloud-computing-for-business-leaders-nanodegree--nd046" aria-label="Cloud Computing for Business Leaders" data-testid="catalog-card-lemur"><article class="_catalog-card-lemur_container__2u2VK"><div class="_catalog-card-lemur_imageContainer__3RKr4"><ul data-mobileonly="true" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><div class="_catalog-card-lemur_programImage__3wQ69" style="background-image:url(...)"></div></div><div class="_catalog-card-lemur_body__2kxzp"><div><ul data-mobileonly="false" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><h2>Cloud Computing for Business Leaders</h2><h3>School of Business</h3><p>This program will focus on the unique knowledge and skills that business leaders need to unlock the value of cloud technologies in their organizations, or enable a more cloud-native department that leverages cloud computing to drive growth and create operational efficiencies.</p></div><ul class="_catalog-card-lemur_stats__S_MFm"><li data-level="intermediate">intermediate</li><li data-duration="">2 Months</li><li></li></ul><div class="_catalog-card-lemur_overview__1apEI"><section><h4>Skills Covered</h4><p>Digital transformation,  leadership,  management,  cloud governance model,  novel cloud services,  operational efficiencies,  cloud center of excellence</p></section><section><h4>Prerequisites</h4><p>Word Processors, Spreadsheets, Presentation Tools</p></section></div></div><div class="_catalog-card-lemur_actionButtonsContainer__3wxO4"><div><button class="btn button--primary">Program Details</button><button class="btn button--white-outlined">Do ...
# </p></section><section><h4>Prerequisites</h4><p>Experience working with command line and virtual machines</p></section></div></div><div class="_catalog-card-lemur_actionButtonsContainer__3wxO4"><div><button class="btn button--primary">Program Details</button><button class="btn button--white-outlined">Download Syllabus</button></div><div><h4>In Collaboration With</h4><p>Nutanix</p></div></div></article></a></li><li class="catalog-card-list_catalogCardListItem__AZBy6"><a href="/course/cloud-developer-using-microsoft-azure-nanodegree--nd081" aria-label="Cloud Developer using Microsoft Azure" data-testid="catalog-card-lemur"><article class="_catalog-card-lemur_container__2u2VK"><div class="_catalog-card-lemur_imageContainer__3RKr4"><ul data-mobileonly="true" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><div class="_catalog-card-lemur_programImage__3wQ69" style="background-image:url(...)"></div></div><div class="_catalog-card-lemur_body__2kxzp"><div><ul data-mobileonly="false" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><h2>Cloud Developer using Microsoft Azure</h2><h3>School of Cloud Computing</h3><p>The Cloud Developer using Microsoft Azure program prepares students with critical cloud computing skills in how to deploy, build, migrate, and monitor applications on Azure.</p></div><ul class="_catalog-card-lemur_stats__S_MFm"><li data-level="intermediate">intermediate</li><li data-duration="">4 Months</li><li></li></ul><div class="_catalog-card-lemur_overview__1apEI"><section><h4>Skills Covered</h4><p>Virtual Machines,  App Services,  Microservices,  Serverless Functions,  Cloud Migration</p></section><section><h4>Prerequisites</h4><p>Intermediate programming experience, familiarity with SQL databases and Git</p></section></div></div><div class="_catalog-card-lemur_actionButtonsContainer__3wxO4"><div><button class="btn button--primary">Program Details</button><button class="btn button--white-outlined">Download Syllabus</button></div><div><h4>In Collaboration With</h4><p>Microsoft</p></div></div></article></a></li><li class="catalog-card-list_catalogCardListItem__AZBy6"><a href="/course/ethical-hacker-nanodegree--nd350" aria-label="Ethical Hacker" data-testid="catalog-card-lemur"><article class="_catalog-card-lemur_container__2u2VK"><div class="_catalog-card-lemur_imageContainer__3RKr4"><ul data-mobileonly="true" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><div class="_catalog-card-lemur_programImage__3wQ69" style="background-image:url(...)"></div></div><div class="_catalog-card-lemur_body__2kxzp"><div><ul data-mobileonly="false" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><h2>Ethical Hacker</h2><h3>School of Cybersecurity</h3><p>Master the skills necessary to become a successful Ethical Hacker. Learn how to find and exploit vulnerabilities and weaknesses in various systems, design and execute a penetration testing plan, and report on test findings using valid evidence.</p></div><ul class="_catalog-card-lemur_stats__S_MFm"><li data-level="advanced">advanced</li><li data-duration="">2 Months</li><li></li></ul><div class="_catalog-card-lemur_overview__1apEI"><section><h4>Skills Covered</h4><p>Vulnerability Management,  Penetration Testing,  Reconnaissance,  Social Engineering,  Open-source intelligence,  System and Application Auditing</p></section><section><h4>Prerequisites</h4><p>Linux, Networking, Programming and Window OS</p></section></div></div><div class="_catalog-card-lemur_actionButtonsContainer__3wxO4"><div><button class="btn button--primary">Program Details</button><button class="btn button--white-outlined">Download Syllabus</button></div></div></article></a></li><li class="catalog-card-list_catalogCardListItem__AZBy6"><a href="/course/security-engineer-nanodegree--nd698" aria-label="Securi ...
# Management, Penetration Testing</p></section><section><h4>Prerequisites</h4><p>Basics of Python, experience configuring AWS and Linux environments</p></section></div></div><div class="_catalog-card-lemur_actionButtonsContainer__3wxO4"><div><button class="btn button--primary">Program Details</button><button class="btn button--white-outlined">Download Syllabus</button></div></div></article></a></li><li class="catalog-card-list_catalogCardListItem__AZBy6"><a href="/course/security-analyst-nanodegree--nd324" aria-label="Security Analyst" data-testid="catalog-card-lemur"><article class="_catalog-card-lemur_container__2u2VK"><div class="_catalog-card-lemur_imageContainer__3RKr4"><ul data-mobileonly="true" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><div class="_catalog-card-lemur_programImage__3wQ69" style="background-image:url(...)"></div></div><div class="_catalog-card-lemur_body__2kxzp"><div><ul data-mobileonly="false" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><h2>Security Analyst</h2><h3>School of Cybersecurity</h3><p>Learn to identify, correct and respond to security weaknesses and incidents. Youâll also get real-world experience monitoring network traffic, analyzing alert and log data, and following incident handling procedures.</p></div><ul class="_catalog-card-lemur_stats__S_MFm"><li data-level="intermediate">intermediate</li><li data-duration="">4 Months</li><li></li></ul><div class="_catalog-card-lemur_overview__1apEI"><section><h4>Skills Covered</h4><p>Security controls,  Defensible Network Architecture,  security threat mitigation,  threat modeling,  vulnerability assessment,  incident detection and handling</p></section><section><h4>Prerequisites</h4><p>Experience with Python, SQL, and security fundamentals</p></section></div></div><div class="_catalog-card-lemur_actionButtonsContainer__3wxO4"><div><button class="btn button--primary">Program Details</button><button class="btn button--white-outlined">Download Syllabus</button></div></div></article></a></li><li class="catalog-card-list_catalogCardListItem__AZBy6"><a href="/course/data-analysis-and-visualization-with-power-BI-nanodegree--nd331" aria-label="Data Analysis and Visualization with Power BI" data-testid="catalog-card-lemur"><article class="_catalog-card-lemur_container__2u2VK"><div class="_catalog-card-lemur_imageContainer__3RKr4"><ul data-mobileonly="true" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><div class="_catalog-card-lemur_programImage__3wQ69" style="background-image:url(...)"></div></div><div class="_catalog-card-lemur_body__2kxzp"><div><ul data-mobileonly="false" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><h2>Data Analysis and Visualization with Power BI</h2><h3>School of Data Science</h3><p>Youâll master the in-demand skills necessary to become a successful data analyst like data pre-processing, visualization and analysis using Power BI as the primary tool.</p></div><ul class="_catalog-card-lemur_stats__S_MFm"><li data-level="beginner">beginner</li><li data-duration="">3 Months</li><li></li></ul><div class="_catalog-card-lemur_overview__1apEI"><section><h4>Skills Covered</h4><p>Power BI,  data visulations,  data modeling,  Extract-Transform-Load,  Data Analytics Expressions</p></section><section><h4>Prerequisites</h4><p>Microsoft Excel</p></section></div></div><div class="_catalog-card-lemur_actionButtonsContainer__3wxO4"><div><button class="btn button--primary">Program Details</button><button class="btn button--white-outlined">Download Syllabus</button></div></div></article></a></li><li class="catalog-card-list_catalogCardListItem__AZBy6"><a href="/course/data-architect-nanodegree--nd038" aria-label="Data Architect" data-testid="catalog-card-lemur"><article class="_catalog-card-lemur_container__2u2VK"><div  ...
# </p></section><section><h4>Prerequisites</h4><p>Intermediate Python, SQL, and Basics of ETL/Data Pipelines</p></section></div></div><div class="_catalog-card-lemur_actionButtonsContainer__3wxO4"><div><button class="btn button--primary">Program Details</button><button class="btn button--white-outlined">Download Syllabus</button></div></div></article></a></li><li class="catalog-card-list_catalogCardListItem__AZBy6"><a href="/course/full-stack-javascript-developer-nanodegree--nd0067" aria-label="Full Stack JavaScript Developer" data-testid="catalog-card-lemur"><article class="_catalog-card-lemur_container__2u2VK"><div class="_catalog-card-lemur_imageContainer__3RKr4"><ul data-mobileonly="true" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><div class="_catalog-card-lemur_programImage__3wQ69" style="background-image:url(...)"></div></div><div class="_catalog-card-lemur_body__2kxzp"><div><ul data-mobileonly="false" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><h2>Full Stack JavaScript Developer</h2><h3>School of Programming &amp; Development</h3><p>Youâll master the skills necessary to become a successful full stack developer. Learn how to build UI and UX, create APIs and server side business logic and develop the persistence layer to store, process and retrieve data.</p></div><ul class="_catalog-card-lemur_stats__S_MFm"><li data-level="intermediate">intermediate</li><li data-duration="">4 Months</li><li></li></ul><div class="_catalog-card-lemur_overview__1apEI"><section><h4>Skills Covered</h4><p>Creating an API,  Databases and SQL,  Node.js,  Angular,  TypeScript,  Deployment</p></section><section><h4>Prerequisites</h4><p>HTML, CSS, Basic JavaScript, JSON</p></section></div></div><div class="_catalog-card-lemur_actionButtonsContainer__3wxO4"><div><button class="btn button--primary">Program Details</button><button class="btn button--white-outlined">Download Syllabus</button></div></div></article></a></li><li class="catalog-card-list_catalogCardListItem__AZBy6"><a href="/course/java-programming-nanodegree--nd079" aria-label="Java Programming" data-testid="catalog-card-lemur"><article class="_catalog-card-lemur_container__2u2VK"><div class="_catalog-card-lemur_imageContainer__3RKr4"><ul data-mobileonly="true" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><div class="_catalog-card-lemur_programImage__3wQ69" style="background-image:url(...)"></div></div><div class="_catalog-card-lemur_body__2kxzp"><div><ul data-mobileonly="false" class="_catalog-card-lemur_featureFlagContainer__2LWr0"><li data-type="new"><small>New</small></li></ul><h2>Java Programming</h2><h3>School of Programming &amp; Development</h3><p>This Nanodegree program is intended to elevate your Java abilities and teach you the fundamental skills used by Java developers to design, code, test and deploy cutting-edge Java software. It is ideal for programming beginners with little or no Java experience who want to set themselves up for success as a professional Java developer and deploy functional Java-based applications of their own creation.</p></div><ul class="_catalog-card-lemur_stats__S_MFm"><li data-level="beginner">beginner</li><li data-duration="">3 Months</li><li></li></ul><div class="_catalog-card-lemur_overview__1apEI"><section><h4>Skills Covered</h4><p>Object-oriented programming,  functional programming,  I/O,  reflection,  concurrent programming,  Java modules</p></section><section><h4>Prerequisites</h4><p>Basic programming concepts like variables, loops and conditionals.</p></section></div></div><div class="_catalog-card-lemur_actionButtonsContainer__3wxO4"><div><button class="btn button--primary">Program Details</button><button class="btn button--white-outlined">Download Syllabus</button></div></div></article></a></li><li class="catalog-card-list_catalogCardListItem__AZBy6"><a href="/cou ...

# %%
import re

pattern = re.compile(r'<.*?>')

print(pattern.sub('', response.text))
# Out:
# window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r,o.inPlace(window.history,["pushState","replaceState"],"-")},{}],7:[function(t,n,e){var r=t("ee").get("raf"),o=t(18)(r),i="equestAnimationFrame";n.exports=r,o.inPlace(window,["r"+i,"mozR"+i,"webkitR"+i,"msR"+i],"raf-"),r.on("raf-start",function(t){t[0]=o(t[0],"fn-")})},{}],8:[function(t,n,e){function r(t,n,e){t[0]=a(t[0],"fn-",null,e)}function o(t,n,e){this.method=e,this.timerDuration=isNaN(t[1])?0:+t[1],t[0]=a(t[0],"fn-",this,e)}var i=t("ee").get("timer"),a=t(18)(i),s="setTimeout",c="setInterval",f="clearTimeout",u="-start",d="-";n.exports=i,a.inPlace(window,[s,"setImmediate"],s+d),a.inPlace(window,[c],c+d),a.inPlace(window,[f,"clearImmediate"],f+d),i.on(c+u,r),i.on(s+u,o)},{}],9:[function(t,n,e){function r(t,n){d.inPlace(n,["onreadystatechange"],"fn-",s)}function o(){var t=this,n=u.context(t);t.readyState>3&&!n.resolved&&(n.resolved=!0,u.emit("xhr-resolved",[],t)),d.inPlace(t,y,"fn-",s)}function i(t){g.push(t),h&&(x?x.then(a):w?w(a):(E=-E,O.data=E))}function a(){for(var t=0;t34||pExplore our Programs and Courses | Udacity Catalog!function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","debug", ...
#         window.addEventListener('load', function() {analytics.page("Catalog", "Catalog - all", {site_identifier: "Next.Sites", ordered_results: "nd027,nd1309,nd002,nd104,nd025,nd018,nd256,nd036,nd213,nd0044,nd880,nd072,nd009t,nd098,nd0011,nd101,nd019,nd000,nd089,nd035,nd578,nd013,nd030,nd545,nd029,nd9991,nd9990,nd891,nd209,nd892,nd893,nd032,nd088,nd028,nd003,nd229,nd144,nd063,nd037-2,nd313,nd113,nd803,nd320,nd008t,nd197,nd230,nd787,nd131,nd037-3,nd082,nd898,nd118,nd054,nd045,nd037,nd00333,nd064,nd046,nd321,nd081,nd350,nd698,nd324,nd331,nd038,nd0067,nd079,nd303,nd940,nd340,ud723,ud509,ud518,ud979,ud034,ud099,ud953,ud741,ud758,ud827,ud132,ud954,ud185,ud919,ud507,ud501,ud262,ud617,ud381,ud257,ud651,ud409,ud190,ud810,ud187,ud104,cs271,cs373,ud188,ud014,ud600,ud120,ud9876,cs222,ud0419,ud0321,ud080,ud459,ud279,ud199,ud977,ud976,ud978,ud981,ud980,ud719,ep245,ud806,ud942,ud359,ud170,ud198,ud150,ud201,ud2002,ud404,ud091,ud892,ud894,ud893,ud595,ud808,ud839,ud884,ud421,ud989,ud836,ud825,ud882,ud774,ud867,ud905,ud898,ud788,ud834,ud897,ud994,ud890,ud855,ud821,ud330,ud585,ud923,ud843,ud891,ud845,ud615,ud9012,ud860,ud902,ud899,ud888,ud849,ud805,ud1006,ud811,ud777,ud333,ud325,ud436,ud353,ud400,ud405,ud245,ud401,ud268,ud406,ud549,ud711,ud610,ud168,ud292,ud283,ud388,ud098,ud803,ud576,ud1022,st101,ud001,ud851,ud1110,ud1012,ud1009,cs258,cs291,ud088,ud007,ud1026,ud9011,ud206,ud1038,st095,cs313,cs212,ud032,ud1025,ud0352,cs259,ud1000,ud1031,cs262,ud256,ph100,ud197,ud356,ud1034,ud110,cs215,ud270,ud667,ud109,ud169,ud281,ud303,ud940,ud061,ud189,ud1028,ud123,ud0351,ud162,ud272,cs387,ud282,ud210,ud171,ud117,ud354,ud299,ud607,ud611,ud864,ud357,ud358,ps001,ud407,ud862,ud244,ud243,ud242,ud944,ud241,ud1001,ud250,ud252,ud1011,ud240,ud251", results_count: "259", category_key: "all"});})ProgramsCareersFor EnterpriseFor GovernmentSign InGet StartedProgramsCareersFor EnterpriseFor GovernmentSign InGet StartedProgram CatalogSearchFilter bySelect Program DetailsTypeProgramsFree CoursesSkill LevelBeginnerIntermediateAdvancedEstimated Duration&lt;1 Month1 - 3 Months3+ MonthsIndustry SkillsSkillsAndroidAndroid DevelopmentAndroid StudioArtificial IntelligenceAWSBusiness StrategyC++Career AdvancementCloudFormationCNNsComputer VisionContinuous DeliveryContinuous IntegrationControlControl FlowCryptographyCSSData AnalysisData ModelingData ScienceData VisualizationData WranglingDebuggingDeep LearningDockerEdge AIEstimationFirebaseFlaskFunctionsGame DevelopmentGrowth StrategyHTMLHybrid CloudImage ClassificationInterview practiceiOSJavaJavaScriptKalman FiltersKotlinKubernetesLocalizationMachine LearningMatplotlibMemory ManagementMicroservicesNatural Language ProcessingNavigationNetworkingNeural NetworksObject TrackingObject-Oriented ProgrammingOptimizationPandasPenetration TestingPerceptionPlanningPostgreSQLPrivate CloudProbabilityProduct DesignProduct ManagementProduct StrategyPrototypingPythonPyTorchRReinforcement LearningServerless ArchitectureSparkSQLSupervised LearningSwiftUIUnsupervised LearningUser ResearchVariables and ConstantsWhiteboardingAllArtificial IntelligenceAI for Business LeadersAI for HealthcareAI Product ManagerAI Programming with PythonArtificial IntelligenceArtificial Intelligence for TradingComputer VisionDeep LearningDeep Reinforcement LearningIntelÂ® Edge AI for IoT DevelopersIntro to Machine Learning with PyTorchIntro to Machine Learning with TensorFlowMachine Learning EngineerMachine Learning Engineer for Microsoft AzureNatural Language ProcessingAutonomous SystemsC++Flying Car and Autonomous Flight EngineerIntro to Self-Driving CarsMachine Learning EngineerRobotics Software EngineerSelf Driving Car EngineerSensor Fusion EngineerBusinessActivation and Retention StrategyAgile Software DevelopmentAI for Business LeadersBusiness AnalyticsCloud Computing for Business LeadersData Product ManagerData Science for Business LeadersDigital MarketingGrowth Product ManagerMarketing AnalyticsMonetization StrategyPredictive Analytics For BusinessProduct ManagerSQ ...
# beginner3 Months91.80327868852459%61 reviewsSkills CoveredAgile, Scrum, Kanban, XP, Minimum Viable ProductPrerequisitesNo Experience RequiredProgram DetailsDownload SyllabusIn Collaboration WithThoughtWorksNewNewAWS Cloud ArchitectSchool of Cloud Computing92.20930232558139%172 reviewsLead your organization&#x27;s cloud computing strategy as an AWS Cloud Architect. Plan, design, and build secure, high availability cloud infrastructure.advanced3 Months92.20930232558139%172 reviewsSkills CoveredCloud Infrastructure, Cloud Security, AWS, CloudFormation, High Availability Infrastructure, Serverless ComputingPrerequisitesExperience with Cloud Computing, Programming, and AWSProgram DetailsDownload SyllabusNewNewActivation and Retention StrategySchool of Product ManagementHone specialized Product Management skills in activation and retention strategy. Guide users through the activation funnel as fast as possible, so they reach your productâs aha-moment, and deploy experiments to improve customer lifetime value and decrease churn.intermediate1 MonthSkills CoveredProduct Management, Activation Funnels, Retention Analysis, Churn Analysis, Segment Analysis, User Engagement, Cohort AnalysisPrerequisitesPrior Product Management Experience RecommendedProgram DetailsDownload SyllabusNewNewSensor Fusion EngineerSchool of Autonomous Systems94.53061224489797%245 reviewsLearn to fuse lidar point clouds, radar signatures, and camera images using Kalman Filters to perceive the environment and detect and track vehicles and pedestrians over time.advanced4 Months94.53061224489797%245 reviewsSkills CoveredPerception, Lidar, Radar, Sensors, Computer VisionPrerequisitesIntermediate C++, Calculus, and ProbabilityProgram DetailsDownload SyllabusIn Collaboration WithMercedes-BenzIntro to Self-Driving CarsSchool of Autonomous Systems93.11239193083574%694 reviewsThis introductory program is the perfect way to start your journey.intermediate4 Months93.11239193083574%694 reviewsSkills CoveredComputer Vision, Machine Learning, Vehicle Motion, ControlPrerequisitesProgramming &amp; MathematicsProgram DetailsDownload SyllabusAndroid BasicsSchool of Programming &amp; Development96.800772449308%3107 reviewsNo programming experience? No Problem! Start developing Android apps today.beginner4 Months96.800772449308%3107 reviewsSkills CoveredAndroid Development, Java programming, Android Studio, XML layouts, Android ViewsPrerequisitesNo Experience Required.Program DetailsDownload SyllabusIn Collaboration WithGoogleNewNewAI for HealthcareSchool of Artificial Intelligence91.42857142857143%112 reviewsBe at the forefront of the revolution of AI in Healthcare, and transform patient outcomes. Enable enhanced medical decision-making powered by machine learning to build the treatments of the future.advanced4 Months91.42857142857143%112 reviewsSkills CoveredArtificial Intelligence, 2D Medical Imaging, 3D Medical Imaging, Electronic Health Record Data, Deep Learning, Wearable Device Data, Supervised LearningPrerequisitesIntermediate Python, and Experience with Machine LearningProgram DetailsDownload SyllabusPredictive Analytics For BusinessSchool of Business94.00457665903889%437 reviewsPredictive analytics is the practice of determining patterns from data to predict future outcomes and trends. Across industries, it enables high-value solutions to important business problems.beginner160 Hours94.00457665903889%437 reviewsSkills CoveredData Wrangling, Classification, A/B Testing, Forecasting, SegmentationPrerequisitesAlgebra, Descriptive Statistics, and ExcelProgram DetailsDownload SyllabusIn Collaboration WithAlteryx, TableauNewNewData VisualizationSchool of Data Science92.35955056179776%178 reviewsCombine data, visuals, and narrative to tell impactful stories and make data-driven decisions.beginner4 Months92.35955056179776%178 reviewsSkills CoveredData Visualization, Tableau, Dashboards, Data StorytellingPrerequisitesBasic Data AnalysisProgram DetailsDownload SyllabusNewNewIntro t ...
# PrerequisitesPrior experience with Python, Machine Learning, and StatisticsProgram DetailsDownload SyllabusIn Collaboration WithMicrosoftNewNewCloud Native Application ArchitectureSchool of Cloud ComputingYouâll master the skills necessary to become a successful cloud native architect. Learn to run and manage scalable applications in a cloud native environment, using open source tools and projects like ArgoCD, gRPC, and Grafana.intermediate4 MonthsSkills CoveredMicroservice architecture,  Kubernetes,  Continuous Integration,  Continuous Delivery,  Message Passing,  Observability,  Microservices securityPrerequisitesHTTP, Python, Git, Linux, DockerProgram DetailsDownload SyllabusIn Collaboration WithSUSENewNewCloud Computing for Business LeadersSchool of BusinessThis program will focus on the unique knowledge and skills that business leaders need to unlock the value of cloud technologies in their organizations, or enable a more cloud-native department that leverages cloud computing to drive growth and create operational efficiencies.intermediate2 MonthsSkills CoveredDigital transformation,  leadership,  management,  cloud governance model,  novel cloud services,  operational efficiencies,  cloud center of excellencePrerequisitesWord Processors, Spreadsheets, Presentation ToolsProgram DetailsDownload SyllabusNewNewHybrid Cloud EngineerSchool of Cloud Computing94.20454545454545%176 reviewsThis Nanodegree program, built in collaboration with experts from Nutanix, a leader in the cutting edge field of hyperconverged infrastructure software, takes cloud technology and data-center professionals on an in-depth journey into the design, deployment, and management of infrastructure and applications together on the Hybrid Cloud. Master the concepts you need to transform how your IT teams manage applications and support the business.intermediate3 Months94.20454545454545%176 reviewsSkills CoveredHyper-converged infrastructure,  Hybrid Cloud,  Public Cloud,  Private Cloud,  HCI Clusters,  Workload Management,  On premise,  Off premise
# PrerequisitesExperience working with command line and virtual machinesProgram DetailsDownload SyllabusIn Collaboration WithNutanixNewNewCloud Developer using Microsoft AzureSchool of Cloud ComputingThe Cloud Developer using Microsoft Azure program prepares students with critical cloud computing skills in how to deploy, build, migrate, and monitor applications on Azure.intermediate4 MonthsSkills CoveredVirtual Machines,  App Services,  Microservices,  Serverless Functions,  Cloud MigrationPrerequisitesIntermediate programming experience, familiarity with SQL databases and GitProgram DetailsDownload SyllabusIn Collaboration WithMicrosoftNewNewEthical HackerSchool of CybersecurityMaster the skills necessary to become a successful Ethical Hacker. Learn how to find and exploit vulnerabilities and weaknesses in various systems, design and execute a penetration testing plan, and report on test findings using valid evidence.advanced2 MonthsSkills CoveredVulnerability Management,  Penetration Testing,  Reconnaissance,  Social Engineering,  Open-source intelligence,  System and Application AuditingPrerequisitesLinux, Networking, Programming and Window OSProgram DetailsDownload SyllabusNewNewSecurity EngineerSchool of CybersecurityTake advantage of the growing need for skilled security professionals by mastering the sought-after skills to protect an organizationâs computer networks and systems from security threats or attacks.intermediate4 MonthsSkills CoveredCryptography, Risk Evaluation, Authentication, Authorization, Access
# Management, Penetration TestingPrerequisitesBasics of Python, experience configuring AWS and Linux environmentsProgram DetailsDownload SyllabusNewNewSecurity AnalystSchool of CybersecurityLearn to identify, correct and respond to security weaknesses and incidents. Youâll also get real-world experience monitoring network traffic, analyzing alert and log data, and following incident handling procedures.intermediate4 MonthsSkills CoveredSecurity controls,  Defensible Network Architecture,  security threat mitigation,  threat modeling,  vulnerability assessment,  incident detection and handlingPrerequisitesExperience with Python, SQL, and security fundamentalsProgram DetailsDownload SyllabusNewNewData Analysis and Visualization with Power BISchool of Data ScienceYouâll master the in-demand skills necessary to become a successful data analyst like data pre-processing, visualization and analysis using Power BI as the primary tool.beginner3 MonthsSkills CoveredPower BI,  data visulations,  data modeling,  Extract-Transform-Load,  Data Analytics ExpressionsPrerequisitesMicrosoft ExcelProgram DetailsDownload SyllabusNewNewData ArchitectSchool of Data ScienceLearn how to plan, design and implement enterprise data infrastructure solutions and create the blueprints for your organizationâs data success.advanced4 MonthsSkills CoveredEntity relationship diagrams,  Relational Data Design,  Online Analytical Processing,  Operational Data Stores,  Data Lake Architecture,  Data Governance
# PrerequisitesIntermediate Python, SQL, and Basics of ETL/Data PipelinesProgram DetailsDownload SyllabusNewNewFull Stack JavaScript DeveloperSchool of Programming &amp; DevelopmentYouâll master the skills necessary to become a successful full stack developer. Learn how to build UI and UX, create APIs and server side business logic and develop the persistence layer to store, process and retrieve data.intermediate4 MonthsSkills CoveredCreating an API,  Databases and SQL,  Node.js,  Angular,  TypeScript,  DeploymentPrerequisitesHTML, CSS, Basic JavaScript, JSONProgram DetailsDownload SyllabusNewNewJava ProgrammingSchool of Programming &amp; DevelopmentThis Nanodegree program is intended to elevate your Java abilities and teach you the fundamental skills used by Java developers to design, code, test and deploy cutting-edge Java software. It is ideal for programming beginners with little or no Java experience who want to set themselves up for success as a professional Java developer and deploy functional Java-based applications of their own creation.beginner3 MonthsSkills CoveredObject-oriented programming,  functional programming,  I/O,  reflection,  concurrent programming,  Java modulesPrerequisitesBasic programming concepts like variables, loops and conditionals.Program DetailsDownload SyllabusNewNewIntermediate PythonSchool of Programming &amp; DevelopmentThe Intermediate Python Nanodegree program teaches intermediate-level skills for programming with the Python language.  It is ideal for developers interested in using Python to build more complex algorithms with greater capabilities in preparation for a variety of different roles spanning fields like data science, AI, and software engineering.intermediate2 MonthsSkills CoveredPython, Object-oriented programming, Modular code, Python Package IndexPrerequisitesBasic PythonProgram DetailsDownload SyllabusNewNewAndroid Kotlin DeveloperSchool of Programming &amp; Development93.83783783783784%185 reviewsMaster Android app development with Kotlin, a modern programming language that enables developers to be more productive.intermediate4 Months93.83783783783784%185 reviewsSkills CoveredAndroid Development, Kotlin, Android Studio, Gradle, RESTful interfaces, Web APIs, App Architecture, Databases, Custom Views, Notifications, Location Services, Testing, FirebasePrerequisitesExperience with Object-Oriented ProgrammingProgram DetailsDownload SyllabusIn Collaboration WithGoogleNewNewRPA Developer with UiPathSchool of Programming &amp; DevelopmentBuild the operational processes that enable the businesses of the future.beginner4 MonthsSkills CoveredProcess Automation, Business Operations, UiPath Studio, UiPath OrchestratorPrerequisitesBasic familiarity with Microsoft applications and data manipulationProgram DetailsDownload SyllabusIn Collaboration WithUiPathFreeFreeRapid PrototypingSchool of Product ManagementLearning to prototype will save you time and money in the development process. Youâll create quality apps faster and have confidence in the viability of your products.intermediate3 WeeksSkills CoveredPrototyping, User Research, inVisionProgram DetailsIn Collaboration WithGoogleFreeFreeProduct DesignSchool of Product ManagementLearn product validation, UI/UX practices, Googleâs Design Sprint and the process for setting and tracking actionable metrics.intermediate2 MonthsSkills CoveredProduct Design, Design Sprints, Ideation and Validation, UI/UXProgram DetailsIn Collaboration WithGoogleFreeFreeApp MonetizationSchool of Product ManagementLearn how to effectively develop, implement, and measure your monetization strategy, iterating on the model as appropriate.intermediate1 MonthSkills CoveredProduct Design, Google AnalyticsProgram DetailsIn Collaboration WithGoogleFreeFreeA/B Testing for Business AnalystsSchool of Product ManagementThe A/B Testing course provides students with the foundational knowledge to design and analyze A/B tests to create business insights and support decision m ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.text, 'html5lib')
print(soup.get_text())
# Out:
# window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(15),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(16),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(18)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(18)(r);n.exports=r,o.inPlace(window.history,["pushState","replaceState"],"-" ...
#         window.addEventListener('load', function() {analytics.page("Catalog", "Catalog - all", {site_identifier: "Next.Sites", ordered_results: "nd027,nd1309,nd002,nd104,nd025,nd018,nd256,nd036,nd213,nd0044,nd880,nd072,nd009t,nd098,nd0011,nd101,nd019,nd000,nd089,nd035,nd578,nd013,nd030,nd545,nd029,nd9991,nd9990,nd891,nd209,nd892,nd893,nd032,nd088,nd028,nd003,nd229,nd144,nd063,nd037-2,nd313,nd113,nd803,nd320,nd008t,nd197,nd230,nd787,nd131,nd037-3,nd082,nd898,nd118,nd054,nd045,nd037,nd00333,nd064,nd046,nd321,nd081,nd350,nd698,nd324,nd331,nd038,nd0067,nd079,nd303,nd940,nd340,ud723,ud509,ud518,ud979,ud034,ud099,ud953,ud741,ud758,ud827,ud132,ud954,ud185,ud919,ud507,ud501,ud262,ud617,ud381,ud257,ud651,ud409,ud190,ud810,ud187,ud104,cs271,cs373,ud188,ud014,ud600,ud120,ud9876,cs222,ud0419,ud0321,ud080,ud459,ud279,ud199,ud977,ud976,ud978,ud981,ud980,ud719,ep245,ud806,ud942,ud359,ud170,ud198,ud150,ud201,ud2002,ud404,ud091,ud892,ud894,ud893,ud595,ud808,ud839,ud884,ud421,ud989,ud836,ud825,ud882,ud774,ud867,ud905,ud898,ud788,ud834,ud897,ud994,ud890,ud855,ud821,ud330,ud585,ud923,ud843,ud891,ud845,ud615,ud9012,ud860,ud902,ud899,ud888,ud849,ud805,ud1006,ud811,ud777,ud333,ud325,ud436,ud353,ud400,ud405,ud245,ud401,ud268,ud406,ud549,ud711,ud610,ud168,ud292,ud283,ud388,ud098,ud803,ud576,ud1022,st101,ud001,ud851,ud1110,ud1012,ud1009,cs258,cs291,ud088,ud007,ud1026,ud9011,ud206,ud1038,st095,cs313,cs212,ud032,ud1025,ud0352,cs259,ud1000,ud1031,cs262,ud256,ph100,ud197,ud356,ud1034,ud110,cs215,ud270,ud667,ud109,ud169,ud281,ud303,ud940,ud061,ud189,ud1028,ud123,ud0351,ud162,ud272,cs387,ud282,ud210,ud171,ud117,ud354,ud299,ud607,ud611,ud864,ud357,ud358,ps001,ud407,ud862,ud244,ud243,ud242,ud944,ud241,ud1001,ud250,ud252,ud1011,ud240,ud251", results_count: "259", category_key: "all"});})ProgramsCareersFor EnterpriseFor GovernmentSign InGet StartedProgramsCareersFor EnterpriseFor GovernmentSign InGet StartedProgram CatalogSearchFilter bySelect Program DetailsTypeProgramsFree CoursesSkill LevelBeginnerIntermediateAdvancedEstimated Duration<1 Month1 - 3 Months3+ MonthsIndustry SkillsSkillsAndroidAndroid DevelopmentAndroid StudioArtificial IntelligenceAWSBusiness StrategyC++Career AdvancementCloudFormationCNNsComputer VisionContinuous DeliveryContinuous IntegrationControlControl FlowCryptographyCSSData AnalysisData ModelingData ScienceData VisualizationData WranglingDebuggingDeep LearningDockerEdge AIEstimationFirebaseFlaskFunctionsGame DevelopmentGrowth StrategyHTMLHybrid CloudImage ClassificationInterview practiceiOSJavaJavaScriptKalman FiltersKotlinKubernetesLocalizationMachine LearningMatplotlibMemory ManagementMicroservicesNatural Language ProcessingNavigationNetworkingNeural NetworksObject TrackingObject-Oriented ProgrammingOptimizationPandasPenetration TestingPerceptionPlanningPostgreSQLPrivate CloudProbabilityProduct DesignProduct ManagementProduct StrategyPrototypingPythonPyTorchRReinforcement LearningServerless ArchitectureSparkSQLSupervised LearningSwiftUIUnsupervised LearningUser ResearchVariables and ConstantsWhiteboardingAllArtificial IntelligenceAI for Business LeadersAI for HealthcareAI Product ManagerAI Programming with PythonArtificial IntelligenceArtificial Intelligence for TradingComputer VisionDeep LearningDeep Reinforcement LearningIntelÂ® Edge AI for IoT DevelopersIntro to Machine Learning with PyTorchIntro to Machine Learning with TensorFlowMachine Learning EngineerMachine Learning Engineer for Microsoft AzureNatural Language ProcessingAutonomous SystemsC++Flying Car and Autonomous Flight EngineerIntro to Self-Driving CarsMachine Learning EngineerRobotics Software EngineerSelf Driving Car EngineerSensor Fusion EngineerBusinessActivation and Retention StrategyAgile Software DevelopmentAI for Business LeadersBusiness AnalyticsCloud Computing for Business LeadersData Product ManagerData Science for Business LeadersDigital MarketingGrowth Product ManagerMarketing AnalyticsMonetization StrategyPredictive Analytics For BusinessProduct ManagerSQLUX ...
# beginner3 Months91.80327868852459%61 reviewsSkills CoveredAgile, Scrum, Kanban, XP, Minimum Viable ProductPrerequisitesNo Experience RequiredProgram DetailsDownload SyllabusIn Collaboration WithThoughtWorksNewNewAWS Cloud ArchitectSchool of Cloud Computing92.20930232558139%172 reviewsLead your organization's cloud computing strategy as an AWS Cloud Architect. Plan, design, and build secure, high availability cloud infrastructure.advanced3 Months92.20930232558139%172 reviewsSkills CoveredCloud Infrastructure, Cloud Security, AWS, CloudFormation, High Availability Infrastructure, Serverless ComputingPrerequisitesExperience with Cloud Computing, Programming, and AWSProgram DetailsDownload SyllabusNewNewActivation and Retention StrategySchool of Product ManagementHone specialized Product Management skills in activation and retention strategy. Guide users through the activation funnel as fast as possible, so they reach your productâs aha-moment, and deploy experiments to improve customer lifetime value and decrease churn.intermediate1 MonthSkills CoveredProduct Management, Activation Funnels, Retention Analysis, Churn Analysis, Segment Analysis, User Engagement, Cohort AnalysisPrerequisitesPrior Product Management Experience RecommendedProgram DetailsDownload SyllabusNewNewSensor Fusion EngineerSchool of Autonomous Systems94.53061224489797%245 reviewsLearn to fuse lidar point clouds, radar signatures, and camera images using Kalman Filters to perceive the environment and detect and track vehicles and pedestrians over time.advanced4 Months94.53061224489797%245 reviewsSkills CoveredPerception, Lidar, Radar, Sensors, Computer VisionPrerequisitesIntermediate C++, Calculus, and ProbabilityProgram DetailsDownload SyllabusIn Collaboration WithMercedes-BenzIntro to Self-Driving CarsSchool of Autonomous Systems93.11239193083574%694 reviewsThis introductory program is the perfect way to start your journey.intermediate4 Months93.11239193083574%694 reviewsSkills CoveredComputer Vision, Machine Learning, Vehicle Motion, ControlPrerequisitesProgramming & MathematicsProgram DetailsDownload SyllabusAndroid BasicsSchool of Programming & Development96.800772449308%3107 reviewsNo programming experience? No Problem! Start developing Android apps today.beginner4 Months96.800772449308%3107 reviewsSkills CoveredAndroid Development, Java programming, Android Studio, XML layouts, Android ViewsPrerequisitesNo Experience Required.Program DetailsDownload SyllabusIn Collaboration WithGoogleNewNewAI for HealthcareSchool of Artificial Intelligence91.42857142857143%112 reviewsBe at the forefront of the revolution of AI in Healthcare, and transform patient outcomes. Enable enhanced medical decision-making powered by machine learning to build the treatments of the future.advanced4 Months91.42857142857143%112 reviewsSkills CoveredArtificial Intelligence, 2D Medical Imaging, 3D Medical Imaging, Electronic Health Record Data, Deep Learning, Wearable Device Data, Supervised LearningPrerequisitesIntermediate Python, and Experience with Machine LearningProgram DetailsDownload SyllabusPredictive Analytics For BusinessSchool of Business94.00457665903889%437 reviewsPredictive analytics is the practice of determining patterns from data to predict future outcomes and trends. Across industries, it enables high-value solutions to important business problems.beginner160 Hours94.00457665903889%437 reviewsSkills CoveredData Wrangling, Classification, A/B Testing, Forecasting, SegmentationPrerequisitesAlgebra, Descriptive Statistics, and ExcelProgram DetailsDownload SyllabusIn Collaboration WithAlteryx, TableauNewNewData VisualizationSchool of Data Science92.35955056179776%178 reviewsCombine data, visuals, and narrative to tell impactful stories and make data-driven decisions.beginner4 Months92.35955056179776%178 reviewsSkills CoveredData Visualization, Tableau, Dashboards, Data StorytellingPrerequisitesBasic Data AnalysisProgram DetailsDownload SyllabusNewNewIntro to Machine Lea ...
# PrerequisitesPrior experience with Python, Machine Learning, and StatisticsProgram DetailsDownload SyllabusIn Collaboration WithMicrosoftNewNewCloud Native Application ArchitectureSchool of Cloud ComputingYouâll master the skills necessary to become a successful cloud native architect. Learn to run and manage scalable applications in a cloud native environment, using open source tools and projects like ArgoCD, gRPC, and Grafana.intermediate4 MonthsSkills CoveredMicroservice architecture,  Kubernetes,  Continuous Integration,  Continuous Delivery,  Message Passing,  Observability,  Microservices securityPrerequisitesHTTP, Python, Git, Linux, DockerProgram DetailsDownload SyllabusIn Collaboration WithSUSENewNewCloud Computing for Business LeadersSchool of BusinessThis program will focus on the unique knowledge and skills that business leaders need to unlock the value of cloud technologies in their organizations, or enable a more cloud-native department that leverages cloud computing to drive growth and create operational efficiencies.intermediate2 MonthsSkills CoveredDigital transformation,  leadership,  management,  cloud governance model,  novel cloud services,  operational efficiencies,  cloud center of excellencePrerequisitesWord Processors, Spreadsheets, Presentation ToolsProgram DetailsDownload SyllabusNewNewHybrid Cloud EngineerSchool of Cloud Computing94.20454545454545%176 reviewsThis Nanodegree program, built in collaboration with experts from Nutanix, a leader in the cutting edge field of hyperconverged infrastructure software, takes cloud technology and data-center professionals on an in-depth journey into the design, deployment, and management of infrastructure and applications together on the Hybrid Cloud. Master the concepts you need to transform how your IT teams manage applications and support the business.intermediate3 Months94.20454545454545%176 reviewsSkills CoveredHyper-converged infrastructure,  Hybrid Cloud,  Public Cloud,  Private Cloud,  HCI Clusters,  Workload Management,  On premise,  Off premise
# PrerequisitesExperience working with command line and virtual machinesProgram DetailsDownload SyllabusIn Collaboration WithNutanixNewNewCloud Developer using Microsoft AzureSchool of Cloud ComputingThe Cloud Developer using Microsoft Azure program prepares students with critical cloud computing skills in how to deploy, build, migrate, and monitor applications on Azure.intermediate4 MonthsSkills CoveredVirtual Machines,  App Services,  Microservices,  Serverless Functions,  Cloud MigrationPrerequisitesIntermediate programming experience, familiarity with SQL databases and GitProgram DetailsDownload SyllabusIn Collaboration WithMicrosoftNewNewEthical HackerSchool of CybersecurityMaster the skills necessary to become a successful Ethical Hacker. Learn how to find and exploit vulnerabilities and weaknesses in various systems, design and execute a penetration testing plan, and report on test findings using valid evidence.advanced2 MonthsSkills CoveredVulnerability Management,  Penetration Testing,  Reconnaissance,  Social Engineering,  Open-source intelligence,  System and Application AuditingPrerequisitesLinux, Networking, Programming and Window OSProgram DetailsDownload SyllabusNewNewSecurity EngineerSchool of CybersecurityTake advantage of the growing need for skilled security professionals by mastering the sought-after skills to protect an organizationâs computer networks and systems from security threats or attacks.intermediate4 MonthsSkills CoveredCryptography, Risk Evaluation, Authentication, Authorization, Access
# Management, Penetration TestingPrerequisitesBasics of Python, experience configuring AWS and Linux environmentsProgram DetailsDownload SyllabusNewNewSecurity AnalystSchool of CybersecurityLearn to identify, correct and respond to security weaknesses and incidents. Youâll also get real-world experience monitoring network traffic, analyzing alert and log data, and following incident handling procedures.intermediate4 MonthsSkills CoveredSecurity controls,  Defensible Network Architecture,  security threat mitigation,  threat modeling,  vulnerability assessment,  incident detection and handlingPrerequisitesExperience with Python, SQL, and security fundamentalsProgram DetailsDownload SyllabusNewNewData Analysis and Visualization with Power BISchool of Data ScienceYouâll master the in-demand skills necessary to become a successful data analyst like data pre-processing, visualization and analysis using Power BI as the primary tool.beginner3 MonthsSkills CoveredPower BI,  data visulations,  data modeling,  Extract-Transform-Load,  Data Analytics ExpressionsPrerequisitesMicrosoft ExcelProgram DetailsDownload SyllabusNewNewData ArchitectSchool of Data ScienceLearn how to plan, design and implement enterprise data infrastructure solutions and create the blueprints for your organizationâs data success.advanced4 MonthsSkills CoveredEntity relationship diagrams,  Relational Data Design,  Online Analytical Processing,  Operational Data Stores,  Data Lake Architecture,  Data Governance
# PrerequisitesIntermediate Python, SQL, and Basics of ETL/Data PipelinesProgram DetailsDownload SyllabusNewNewFull Stack JavaScript DeveloperSchool of Programming & DevelopmentYouâll master the skills necessary to become a successful full stack developer. Learn how to build UI and UX, create APIs and server side business logic and develop the persistence layer to store, process and retrieve data.intermediate4 MonthsSkills CoveredCreating an API,  Databases and SQL,  Node.js,  Angular,  TypeScript,  DeploymentPrerequisitesHTML, CSS, Basic JavaScript, JSONProgram DetailsDownload SyllabusNewNewJava ProgrammingSchool of Programming & DevelopmentThis Nanodegree program is intended to elevate your Java abilities and teach you the fundamental skills used by Java developers to design, code, test and deploy cutting-edge Java software. It is ideal for programming beginners with little or no Java experience who want to set themselves up for success as a professional Java developer and deploy functional Java-based applications of their own creation.beginner3 MonthsSkills CoveredObject-oriented programming,  functional programming,  I/O,  reflection,  concurrent programming,  Java modulesPrerequisitesBasic programming concepts like variables, loops and conditionals.Program DetailsDownload SyllabusNewNewIntermediate PythonSchool of Programming & DevelopmentThe Intermediate Python Nanodegree program teaches intermediate-level skills for programming with the Python language.  It is ideal for developers interested in using Python to build more complex algorithms with greater capabilities in preparation for a variety of different roles spanning fields like data science, AI, and software engineering.intermediate2 MonthsSkills CoveredPython, Object-oriented programming, Modular code, Python Package IndexPrerequisitesBasic PythonProgram DetailsDownload SyllabusNewNewAndroid Kotlin DeveloperSchool of Programming & Development93.83783783783784%185 reviewsMaster Android app development with Kotlin, a modern programming language that enables developers to be more productive.intermediate4 Months93.83783783783784%185 reviewsSkills CoveredAndroid Development, Kotlin, Android Studio, Gradle, RESTful interfaces, Web APIs, App Architecture, Databases, Custom Views, Notifications, Location Services, Testing, FirebasePrerequisitesExperience with Object-Oriented ProgrammingProgram DetailsDownload SyllabusIn Collaboration WithGoogleNewNewRPA Developer with UiPathSchool of Programming & DevelopmentBuild the operational processes that enable the businesses of the future.beginner4 MonthsSkills CoveredProcess Automation, Business Operations, UiPath Studio, UiPath OrchestratorPrerequisitesBasic familiarity with Microsoft applications and data manipulationProgram DetailsDownload SyllabusIn Collaboration WithUiPathFreeFreeRapid PrototypingSchool of Product ManagementLearning to prototype will save you time and money in the development process. Youâll create quality apps faster and have confidence in the viability of your products.intermediate3 WeeksSkills CoveredPrototyping, User Research, inVisionProgram DetailsIn Collaboration WithGoogleFreeFreeProduct DesignSchool of Product ManagementLearn product validation, UI/UX practices, Googleâs Design Sprint and the process for setting and tracking actionable metrics.intermediate2 MonthsSkills CoveredProduct Design, Design Sprints, Ideation and Validation, UI/UXProgram DetailsIn Collaboration WithGoogleFreeFreeApp MonetizationSchool of Product ManagementLearn how to effectively develop, implement, and measure your monetization strategy, iterating on the model as appropriate.intermediate1 MonthSkills CoveredProduct Design, Google AnalyticsProgram DetailsIn Collaboration WithGoogleFreeFreeA/B Testing for Business AnalystsSchool of Product ManagementThe A/B Testing course provides students with the foundational knowledge to design and analyze A/B tests to create business insights and support decision making.intermediate3  ...
